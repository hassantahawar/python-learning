# %%
from transformers import pipeline
import torch

# %%
generator = pipeline("text-generation")
# Out:
# No model was supplied, defaulted to openai-community/gpt2 and revision 607a30d (https://huggingface.co/openai-community/gpt2).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# Device set to use mps:0
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# [{'generated_text': "In this course, we will teach you how to create and publish CSS classes to provide an easy and reliable way to configure your own CSS classes in a number of ways.\n\nUsing the CSS Classes\n\nIf you need a refresher on something, here's a short explanation of what CSS classes are and why they are important:\n\nCSS classes are a very powerful tool for creating, managing, and deploying web pages. They can easily be used in many different contexts, from design to presentation. They are used to create a set of web page layouts, and many more.\n\nCSS classes are a very powerful tool for creating, managing, and deploying web pages. They can easily be used in many different contexts, from design to presentation. They are used to create a set of web page layouts, and many more. CSS classes are a great way to create a rich set of design-specific CSS classes that can be used by websites to customize their layouts.\n\nCSS classes are a great way to create a rich set of design-specific CSS classes that can be used by websites to customize their layouts. CSS classes are great for creating a variety of HTML templates that are useful for building your own web pages.\n\nCSS classes are great for creating a range of HTML templates that are useful for building your own"}]

# %%
classifier = pipeline("zero-shot-classification")
# Out:
# No model was supplied, defaulted to facebook/bart-large-mnli and revision d7645e1 (https://huggingface.co/facebook/bart-large-mnli).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# Device set to use mps:0

# %%
generator("Cricket Australia is a strong")
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# [{'generated_text': 'Cricket Australia is a strong team who is well respected in Europe. As a result, we are a very consistent team.\n\n"Our focus is to make sure we are the perfect team for the European competition.\n\n"We have been playing in Spain for 10 years so we are also very focused on improving our competitive spirit.\n\n"We are very proud of the team we have played for and our team is not only good, it is very professional.\n\n"The team we have played for is very well organised and we have worked hard to try and improve their behaviour and in the end they have shown we are not just good, we are very good."\n\nThe first-half goal from Chris Brunt and a second from Mark McGhee in the third minute led to a fine run of form from the match and saw the side continue to dominate the game.\n\nThe hosts continued their dominance with Brunt\'s goal and Brunt\'s volley winning second-half the game as the hosts went into the break with four points.\n\nWith three minutes remaining, the hosts were down 3-1 after a penalty from Mark McGhee. However, the visitors made no attempt to score and were fortunate to have a chance to equalise in the second half.\n\nIn'}]

# %%
classifier(
    "Floyd gets away",
    candidate_labels=["education", "politics", "sports", "war", "crime"],
)
# Out:
# {'sequence': 'Floyd gets away',
#  'labels': ['crime', 'politics', 'sports', 'war', 'education'],
#  'scores': [0.6764202117919922,
#   0.11229861527681351,
#   0.09764926880598068,
#   0.058970917016267776,
#   0.05466094985604286]}
